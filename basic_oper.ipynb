# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93158f50-779b-4618-8f04-bc6f5843ca05" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93158f50-779b-4618-8f04-bc6f5843ca05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Mall_Customers.csv to Mall_Customers.csv

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
print(df)
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
df=pd.read_csv('Mall_Customers.csv',index_col=2)
df
# Out:
#      CustomerID   Genre  Annual_Income_(k$)  Spending_Score
# Age
# 19            1    Male                  15              39
# 21            2    Male                  15              81
# 20            3  Female                  16               6
# 23            4  Female                  16              77
# 31            5  Female                  17              40
# ..          ...     ...                 ...             ...
# 35          196  Female                 120              79
# 45          197  Female                 126              28
# 32          198    Male                 126              74
# 32          199    Male                 137              18
# 30          200    Male                 137              83
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#      CustomerID   Genre  Annual_Income_(k$)  Spending_Score
# Age
# 19            1    Male                  15              39
# 21            2    Male                  15              81
# 20            3  Female                  16               6
# 23            4  Female                  16              77
# 31            5  Female                  17              40

# %%
df1=df.head(2).append(df.tail(2))
df1
# Out:
#      CustomerID Genre  Annual_Income_(k$)  Spending_Score
# Age
# 19            1  Male                  15              39
# 21            2  Male                  15              81
# 32          199  Male                 137              18
# 30          200  Male                 137              83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 19 to 30
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          200 non-null    int64
#  1   Genre               200 non-null    object
#  2   Annual_Income_(k$)  200 non-null    int64
#  3   Spending_Score      200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.8+ KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df1=df.append(df)
df1
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [400 rows x 5 columns]

# %%
df=df.drop_duplicates()
print(df.shape)
# Out:
# (200, 5)

# %%
df=df.append(df)
print(df.shape)
# Out:
# (400, 5)

# %%
df=df.drop_duplicates(keep='last',ignore_index=True)
print(df.shape)
print(df)
# Out:
# (200, 5)
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
print(df.columns)
# Out:
# Index(['CustomerID', 'Genre', 'Annual_Income_(k$)', 'Spending_Score'], dtype='object')

# %%
df=df.rename(columns={'Genre' : 'Gender'})
print(df.columns)
# Out:
# Index(['CustomerID', 'Gender', 'Annual_Income_(k$)', 'Spending_Score'], dtype='object')

# %%
df
# Out:
#      CustomerID  Gender  Annual_Income_(k$)  Spending_Score
# 0             1    Male                  15              39
# 1             2    Male                  15              81
# 2             3  Female                  16               6
# 3             4  Female                  16              77
# 4             5  Female                  17              40
# ..          ...     ...                 ...             ...
# 195         196  Female                 120              79
# 196         197  Female                 126              28
# 197         198    Male                 126              74
# 198         199    Male                 137              18
# 199         200    Male                 137              83
#
# [200 rows x 4 columns]

# %%
df.describe() #gives summary statistics for numerical columns in our DataFrame
# Out:
#        CustomerID         Age  Annual_Income_(k$)  Spending_Score
# count  200.000000  200.000000          200.000000      200.000000
# mean   100.500000   38.850000           60.560000       50.200000
# std     57.879185   13.969007           26.264721       25.823522
# min      1.000000   18.000000           15.000000        1.000000
# 25%     50.750000   28.750000           41.500000       34.750000
# 50%    100.500000   36.000000           61.500000       50.000000
# 75%    150.250000   49.000000           78.000000       73.000000
# max    200.000000   70.000000          137.000000       99.000000

# %%
df['Gender'].describe()
# Out:
# count        200
# unique         2
# top       Female
# freq         112
# Name: Gender, dtype: object

# %%
df1=df[['Gender']]
df1
# Out:
#      Gender
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4    Female
# ..      ...
# 195  Female
# 196  Female
# 197    Male
# 198    Male
# 199    Male
#
# [200 rows x 1 columns]

# %%
df1=df[0:4]
df1
# Out:
#      CustomerID   Genre  Annual_Income_(k$)  Spending_Score
# Age
# 19            1    Male                  15              39
# 21            2    Male                  15              81
# 20            3  Female                  16               6
# 23            4  Female                  16              77

# %%
df=pd.read_csv('Mall_Customers.csv',index_col=0)
df
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 1             Male   19                  15              39
# 2             Male   21                  15              81
# 3           Female   20                  16               6
# 4           Female   23                  16              77
# 5           Female   31                  17              40
# ...            ...  ...                 ...             ...
# 196         Female   35                 120              79
# 197         Female   45                 126              28
# 198           Male   32                 126              74
# 199           Male   32                 137              18
# 200           Male   30                 137              83
#
# [200 rows x 4 columns]

# %%
print(df.loc[4])
# Out:
# Genre                 Female
# Age                       23
# Annual_Income_(k$)        16
# Spending_Score            77
# Name: 4, dtype: object

# %%
print(df.loc[[2,4,5]])
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 2           3  Female   20                  16               6
# 4           5  Female   31                  17              40
# 5           6  Female   22                  17              76

# %%
print(df.dtypes)
# Out:
# CustomerID             int64
# Genre                 object
# Age                    int64
# Annual_Income_(k$)     int64
# Spending_Score         int64
# dtype: object

# %%
df2=df.sample(n=3, random_state=2)
df2
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 112         113  Female   38                  64              42
# 29           30  Female   23                  29              87
# 182         183    Male   46                  98              15

# %%
df2=df.sample(n=3, random_state=3)
df2
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 40           41  Female   65                  38              35
# 51           52    Male   33                  42              60
# 139         140  Female   35                  74              72

# %%
df3=df.sample(frac=.25)
print(df3)
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 22            Male   25                  24              73
# 95          Female   32                  60              42
# 117         Female   63                  65              43
# 32          Female   21                  30              73
# 122         Female   38                  67              40
# 130           Male   38                  71              75
# 161         Female   56                  79              35
# 26            Male   29                  28              82
# 183           Male   46                  98              15
# 29          Female   40                  29              31
# 40          Female   20                  37              75
# 92            Male   18                  59              41
# 20          Female   35                  23              98
# 163           Male   19                  81               5
# ...

# %%
df2=df.sample(n=1,random_state=4)
df2
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 12          Female   35                  19              99

# %%
df3=df.sample(n=1)
df3
# Out:
#            Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 108         Male   54                  63              46

# %%
df3=df.sample()
df3
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 182         Female   32                  97              86

# %%
df3=df.sample(n=6)
df3
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 72          Female   47                  49              42
# 182         Female   32                  97              86
# 100           Male   20                  61              49
# 199           Male   32                 137              18
# 170           Male   32                  87              63
# 21            Male   35                  24              35

# %%
df3=df3.sample(n=2,random_state=1)
df3
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 100           Male   20                  61              49
# 182         Female   32                  97              86

# %%
df3
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 100           Male   20                  61              49
# 182         Female   32                  97              86

# %%
df4=df['Age'].value_counts()
df4
# Out:
# 32    11
# 35     9
# 19     8
# 31     8
# 30     7
# 49     7
# 40     6
# 38     6
# 47     6
# 27     6
# 36     6
# 23     6
# 34     5
# 20     5
# 29     5
# 50     5
# 48     5
# 21     5
# 24     4
# 18     4
# 28     4
# 67     4
# 59     4
# 54     4
# 43     3
# 60     3
# 45     3
# 39     3
# 33     3
# 37     3
# 22     3
# 25     3
# 46     3
# 68     3
# 52     2
# 44     2
# 66     2
# 57     2
# 26     2
# 53     2
# 42     2
# 63     2
# 70     2
# 51     2
# 58     2
# 65     2
# 41     2
# 55     1
# 69     1
# 64     1
# 56     1
# Name: Age, dtype: int64

# %%
df4=df['Age'].value_counts(normalize=True)
df4
# Out:
# 32    0.055
# 35    0.045
# 19    0.040
# 31    0.040
# 30    0.035
# 49    0.035
# 40    0.030
# 38    0.030
# 47    0.030
# 27    0.030
# 36    0.030
# 23    0.030
# 34    0.025
# 20    0.025
# 29    0.025
# 50    0.025
# 48    0.025
# 21    0.025
# 24    0.020
# 18    0.020
# 28    0.020
# 67    0.020
# 59    0.020
# 54    0.020
# 43    0.015
# 60    0.015
# 45    0.015
# 39    0.015
# 33    0.015
# 37    0.015
# 22    0.015
# 25    0.015
# 46    0.015
# 68    0.015
# 52    0.010
# 44    0.010
# 66    0.010
# 57    0.010
# 26    0.010
# 53    0.010
# 42    0.010
# 63    0.010
# 70    0.010
# 51    0.010
# 58    0.010
# 65    0.010
# 41    0.010
# 55    0.005
# 69    0.005
# 64    0.005
# 56    0.005
# Name: Age, dtype: float64

# %%
df5=df.value_counts(dropna=False)
df5
# Out:
# Genre   Age  Annual_Income_(k$)  Spending_Score
# Female  18   65                  48                1
# Male    29   28                  82                1
#         24   60                  52                1
#         25   24                  73                1
#              77                  12                1
#                                                   ..
# Female  41   99                  39                1
#              103                 17                1
#         42   34                  17                1
#         43   48                  50                1
# Male    70   49                  55                1
# Length: 200, dtype: int64

# %%
print(df.plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(df.head().plot(kind='area',x='Age',y='Spending_Score'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(df.sort_values('Spending_Score',ascending=True,inplace=True,kind='quicksort',na_position='first'))
# Out:
# None

# %%
df
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 157           Male   37                  78               1
# 159           Male   34                  78               1
# 9             Male   64                  19               3
# 31            Male   60                  30               4
# 33            Male   53                  33               4
# ...            ...  ...                 ...             ...
# 168         Female   33                  86              95
# 186           Male   30                  99              97
# 146           Male   28                  77              97
# 20          Female   35                  23              98
# 12          Female   35                  19              99
#
# [200 rows x 4 columns]

# %%
df7=df.iloc[1:8, 1:3]
df7
# Out:
#             Age  Annual_Income_(k$)
# CustomerID
# 159          34                  78
# 9            64                  19
# 31           60                  30
# 33           53                  33
# 141          57                  75
# 135          20                  73
# 23           46                  25

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-5b15b8961fb8> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# ...
